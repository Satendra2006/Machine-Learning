# %% [markdown]
# # 20th june 2025
# # matplotlib

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
week=[1,2,3,4,5,6,7]
temp=[32,34,35,36,38,35,34]

plt.plot(week,temp)

# %%
plt.plot(week,temp)
plt.xlabel("Days")
plt.ylabel("Temp")
# Out:
# Text(0, 0.5, 'Temp')

# %%
plt.plot(week,temp,c='magenta')
plt.xlabel("Days")
plt.ylabel("Temp")
# Out:
# Text(0, 0.5, 'Temp')

# %%
plt.plot(week,temp)
plt.xlabel("Days")
plt.ylabel("Temp")
plt.title("Silicon University weather")
# Out:
# Text(0.5, 1.0, 'Silicon University weather')

# %%
plt.plot(week,temp,c='#FFA500',ls=":",marker='<')
plt.xlabel("Days")
plt.ylabel("Temp")
plt.title("Silicon University weather")
# Out:
# Text(0.5, 1.0, 'Silicon University weather')

# %%
plt.plot(week,temp,c='#FFA500',ls=":",marker='<',ms=20.5)
plt.xlabel("Days")
plt.ylabel("Temp")
plt.title("Silicon University weather")
# Out:
# Text(0.5, 1.0, 'Silicon University weather')

# %%
plt.plot(week,temp,'o--g',ms=7)
plt.xlabel("Days")
plt.ylabel("Temp")
plt.title("Silicon University weather")
# Out:
# Text(0.5, 1.0, 'Silicon University weather')

# %%
plt.plot(week,temp,'ro:',ms=7)
plt.xlabel("Days")
plt.ylabel("Temp")
plt.title("Silicon University weather")
# Out:
# Text(0.5, 1.0, 'Silicon University weather')

# %%
days=[1,2,3,4,5,6,7] #weekdays
max_t=[50,51,52,48,47,49,46] #max temp recorder at that day
min_t=[43,42,40,44,45,35,37] #min temp
avg_t=[45,48,48,46,40,42,41] # avg temp

# %%
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend()

# %%
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc="lower left")

# %%
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc="center left")

# %%
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc=1)

# %%
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc=5)

# %%
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc=0)

# %%
plt.plot(days,max_t,label="max",ls=":",marker='>')
plt.plot(days,min_t,label="min",ls=":",marker='>')
plt.plot(days,avg_t,label="avg",ls=":",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc=0)
plt.grid()

# %% [markdown]
# # Bar Graph

# %%
company=['Google','MSFT','FB','Twitter']
stock=[234,344,545,656]

# %%
plt.bar(company,stock)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,stock)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Histogram

# %%
blood_sugar=[113,122,80,99,112,87,130,150,88,78,94]

# %%
plt.hist(blood_sugar)
# Out:
# (array([2., 2., 2., 0., 2., 0., 1., 1., 0., 1.]),
#  array([ 78. ,  85.2,  92.4,  99.6, 106.8, 114. , 121.2, 128.4, 135.6,
#         142.8, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,bins=[78,100,125,150])
# Out:
# (array([6., 3., 2.]),
#  array([ 78., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar,bins=[78,100,125,150],histtype='step')
# Out:
# (array([6., 3., 2.]),
#  array([ 78., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x2166d252360>])

# %%
blood_sugar_men=[113,85,90,150,149,88,93,115,135,80,77,82,129]
blood_sugar_women=[67,98,89,120,133,150,84,69,89,79,120,112,100]

# %%
plt.hist([blood_sugar_men,blood_sugar_women],bins=[78,100,125,150],color=['green','orange'],label=['Men','Women'])
plt.legend("Men vs Women")

# %% [markdown]
# # Pie Chart

# %%
exp_values=[1500,800,300,410,250]
exp_labels=['Rent','Travel','Mobile Bill','Food','Others']

# %%
plt.pie(exp_values)
plt.show()

# %%
plt.pie(exp_values,labels=exp_labels)
plt.show()

# %%
plt.pie(exp_values,labels=exp_labels,autopct='%.0f%%')
plt.show()

# %%
plt.pie(exp_values,labels=exp_labels,autopct='%.2f%%')
plt.show()

# %%
plt.pie(exp_values,labels=exp_labels,autopct='%.2f%%',radius=2)
plt.show()

# %%
plt.pie(exp_values,labels=exp_labels,explode=[0,0,0.5,0,0],autopct='%.2f%%',radius=2)
plt.show()

# %%
plt.pie(exp_values,labels=exp_labels,explode=[0,0.3,0.3,0.3,0.3],autopct='%.2f%%',radius=2)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(blood_sugar_men,blood_sugar_women)

# %%
plt.scatter(blood_sugar_men,blood_sugar_women)
plt.title("Men Blood Sugar vs Women Blood Sugar")
plt.xlabel("Men Blood Sugar")
plt.ylabel("Women Blood Sugar")
plt.grid()
plt.show()
plt.savefig("scatter.fig")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 7
#       5 plt.grid()
#       6 plt.show()
# ----> 7 plt.savefig("scatter.fig")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# ...

# %%
plt.boxplot(exp_values,exp_labels,labels=[exp_values,exp_labels])
plt.title("box plot")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8956\1505901695.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(exp_values,exp_labels,labels=[exp_values,exp_labels])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 plt.boxplot(exp_values,exp_labels,labels=[exp_values,exp_labels])
#       2 plt.title("box plot")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
# ...

# %%
plt.subplot(2,2,1)
plt.pie(exp_values,labels=exp_labels,autopct='%.2f%%')

plt.subplot(2,2,4)
plt.hist([blood_sugar_men,blood_sugar_women],bins=[78,100,125,150],color=['green','orange'],label=['Men','Women'])
plt.legend("Men vs Women")

# %%
plt.subplot(3,3,1)
plt.pie(exp_values,labels=exp_labels,autopct='%.2f%%')

plt.subplot(3,3,5)
plt.hist([blood_sugar_men,blood_sugar_women],bins=[78,100,125,150],color=['green','orange'],label=['Men','Women'])
plt.legend("Men vs Women")

plt.subplot(3,3,9)
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')

plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
plt.legend(loc=0)

# %%
plt.subplot(3,3,1)
plt.pie(exp_values,labels=exp_labels,autopct='%.2f%%')

plt.subplot(3,3,3)
plt.hist([blood_sugar_men,blood_sugar_women],bins=[78,100,125,150],color=['green','orange'],label=['Men','Women'])

plt.subplot(3,3,8)
plt.plot(days,max_t,label="max",marker='>')
plt.plot(days,min_t,label="min",marker='>')
plt.plot(days,avg_t,label="avg",marker='>')
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Bhubaneswar Weather")
# Out:
# Text(0.5, 1.0, 'Bhubaneswar Weather')

# %%
import seaborn as sns

# %%
#load built-in dataset
iris=sns.load_dataset("iris")
tips=sns.load_dataset("tips")
penguins=sns.load_dataset("penguins")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data=tips,x='tip',fill=True)
plt.title("kde plot for tips")
plt.show()

# %%
sns.histplot(tips)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(data=tips, y='total bill')
plt.title("Box plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 sns.boxplot(data=tips, y='total bill')
#       2 plt.title("Box plot")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.violinplot(data=iris,x='species',y='sepal_length')
plt.title("Violin plot")
plt.show()

# %%
sns.scatterplot(data=iris,x="sepal_length",y='petal_length',hue='species')
plt.title("scatter plot")
plt.show()

# %%
sns.pairplot(iris,hue="species")
plt.subtitle("Pair plot of iris",y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 2
#       1 sns.pairplot(iris,hue="species")
# ----> 2 plt.subtitle("Pair plot of iris",y=1.02)
#       3 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'subtitle'

# %%
# Heatmap
corr=tips.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
